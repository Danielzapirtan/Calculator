# %%
# %cd /content/
# !rm -rf Calculator
# !apt install git build-essential
# !git clone https://github.com/Danielzapirtan/Calculator.git
# %cd Calculator
# !git switch cli-version
# !gcc -fsyntax-only clicalc.h && echo "Compiled ok"
# Out:
# /content
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# git is already the newest version (1:2.34.1-1ubuntu1.15).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# Cloning into 'Calculator'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 47 (delta 17), reused 14 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (47/47), 1.42 MiB | 35.55 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# /content/Calculator
# Branch 'cli-version' set up to track remote branch 'cli-version' from 'origin'.
# Switched to a new branch 'cli-version'
